# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# LINE PLOT

# %%
x=[1,2,3,4,5,6,7]
y=[10,30,20,50,70,60,50]
df=pd.DataFrame({'days':x,'no. of people':y})
df
# Out:
#    days  no. of people
# 0     1             10
# 1     2             30
# 2     3             20
# 3     4             50
# 4     5             70
# 5     6             60
# 6     7             50

# %%
sns.lineplot(x='days',y='no. of people',data=df)
plt.show()
#plt.style.use('dark_background')

# %%
df=pd.read_excel("C:\\Users\\PANDEY JI\\Desktop\\PYTHON\\tips.xlsx")
df
# Out:
#    Total Bill   Tip  Gender Drinks  Day    Time  Size
# 0       16.99  1.01  Female    Yes  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun   Lunch     3
# 2       21.01  3.51    Male     No  Mon  Dinner     5
# 3       23.68  3.31    Male    Yes  Fri   Lunch     2
# 4       24.59  3.61  Female    Yes  Fri   Lunch     3

# %%
#sns.lineplot(x='Day',y='Total Bill',data=df)
sns.lineplot(x='Day',y='Total Bill',data=df,hue='Gender')
#sns.lineplot(x='Day',y='Total Bill',data=df,hue='Gender',style='Time')
plt.show()

# %% [markdown]
# BAR PLOT

# %%
sns.barplot(x='Day',y='Total Bill',data=df, hue='Day', palette='pastel', legend=False) #black line on top of bar represent 'MEDIAN'
# Out:
# <Axes: xlabel='Day', ylabel='Total Bill'>

# %%
from numpy import mean
sns.barplot(x='Day',y='Total Bill',data=df,estimator=mean,hue='Day', palette='pastel', legend=False) #black line on top of bar represent 'MEAN'
# Out:
# <Axes: xlabel='Day', ylabel='Total Bill'>

# %%
from numpy import median
sns.barplot(x='Day',y='Total Bill',data=df,estimator=median,hue='Day', palette='pastel', legend=False) #black line on top of bar represent 'MEDIAN'
#default is median
# Out:
# <Axes: xlabel='Day', ylabel='Total Bill'>

# %%
sns.barplot(x='Day',y='Total Bill',data=df,hue='Day', palette='pastel', legend=False) #to remove black line on top of bar.
# Out:
# <Axes: xlabel='Day', ylabel='Total Bill'>

# %%
sns.barplot(x='Day',y='Total Bill',data=df,order=['Mon','Fri','Sun'],hue='Day', palette='pastel', legend=False) #to change the order
# Out:
# <Axes: xlabel='Day', ylabel='Total Bill'>

# %%
sns.barplot(x='Total Bill',y='Day',data=df,hue='Day', palette='pastel', legend=False) #horizontal bar
plt.show()

# %%
sns.barplot(x='Day',y='Total Bill',data=df,color='magenta')
plt.show()

# %%
sns.barplot(x='Day',y='Total Bill',data=df,hue='Gender')
plt.show()

# %%
sns.barplot(x='Day',y='Total Bill',data=df,hue='Gender',palette='flare') #to change color
#sns.barplot(x='Day',y='Total Bill',data=df,hue='Gender',palette='spring')
plt.show()

# %%
sns.barplot(x='Day',y='Total Bill',data=df,hue='Gender',palette='spring',saturation=0.2) #sharpness
# Out:
# <Axes: xlabel='Day', ylabel='Total Bill'>

# %% [markdown]
# HISTOGRAM PLOT

# %%
sns.histplot(x='Day',data=df)
# Out:
# <Axes: xlabel='Day', ylabel='Count'>

# %%
sns.histplot(x='Day',data=df,color='yellow')
# Out:
# <Axes: xlabel='Day', ylabel='Count'>

# %%
sns.histplot(x='Drinks',data=df)
plt.show()

# %%
sns.histplot(x='Day',data=df,discrete=False) #to give space
# Out:
# <Axes: xlabel='Day', ylabel='Count'>

# %%
sns.histplot(x='Drinks',data=df,hue='Gender',discrete=False) #gray color is overlaping data
# Out:
# <Axes: xlabel='Drinks', ylabel='Count'>

# %%
sns.histplot(x='Drinks',data=df,hue='Gender',discrete=False,edgecolor='red')
# Out:
# <Axes: xlabel='Drinks', ylabel='Count'>

# %%
sns.histplot(x='Drinks',data=df,hue='Gender',discrete=False,linestyle='--',edgecolor='red')
# Out:
# <Axes: xlabel='Drinks', ylabel='Count'>

# %%
sns.histplot(x='Drinks',data=df,hue='Gender',discrete=False,kde=True)
# Out:
# <Axes: xlabel='Drinks', ylabel='Count'>

# %% [markdown]
# SCATTER PLOT

# %%
df1=pd.read_csv("C:\\Users\\PANDEY JI\\Desktop\\PYTHON\\IPL.csv")
df1
sns.scatterplot(x='city',y='winner',data=df1)
plt.show()

# %%
sns.scatterplot(x='city',y='winner',data=df1,hue='toss_decision')
plt.show()

# %%
sns.scatterplot(x='city',y='winner',data=df1,size='toss_decision')
plt.show()

# %%
#sns.scatterplot(x='city',y='winner',data=df1,hue='toss_decision',marker='D') #DIAMOND
#sns.scatterplot(x='city',y='winner',data=df1,hue='toss_decision',marker='*') #star
sns.scatterplot(x='city',y='winner',data=df1,hue='toss_decision',marker='s') #square
plt.show()

# %%
#sns.scatterplot(x='city',y='winner',data=df1,hue='toss_decision',marker='D',alpha=.1) #hazy color
sns.scatterplot(x='city',y='winner',data=df1,hue='toss_decision',marker='D',alpha=.5) #half transparent
plt.show()

# %% [markdown]
# BOX PLOT

# %%
sns.boxplot(x=df['Total Bill'],data=df)
plt.show()

# %%
sns.boxplot(x='Gender',y='Tip',data=df)
plt.show()

# %%
sns.boxplot(x='Gender',y='Tip',data=df,hue='Drinks')
plt.show()

# %%
sns.boxplot(x='Gender',y='Tip',data=df,palette='viridis')
plt.show()
# Out:
# C:\Users\PANDEY JI\AppData\Local\Temp\ipykernel_100\4080768277.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Gender',y='Tip',data=df,palette='viridis')

# %%
sns.boxplot(x='Gender',y='Tip',data=df,color='hotpink',linewidth=3)
plt.show()

# %%
sns.boxplot(data=df,orient='h') #horizontal view
plt.show()

# %%
sns.boxplot(data=df['Tip'],orient='v') #vertical view
plt.show()

# %%
sns.set(style='whitegrid')
sns.boxplot(x='Gender',y='Tip',data=df)
plt.show()

# %% [markdown]
# KERNEL DENSITY ESTIMATION (KDE)

# %%
sns.get_dataset_names() #to see the available dataset on internet.
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df2=sns.load_dataset('tips').dropna() #to load available dataset
df2.head(7)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2

# %%
df3=sns.load_dataset('titanic') #to load available dataset
df3.head(7)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# ...

# %%
df3.shape
# Out:
# (891, 15)

# %%
titanic['age'].fillna(titanic['age'].mean(),inplace=True)
sns.displot(titanic['age'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 titanic['age'].fillna(titanic['age'].mean(),inplace=True)
#       2 sns.displot(titanic['age'])
#       3 plt.show()
#
# NameError: name 'titanic' is not defined
