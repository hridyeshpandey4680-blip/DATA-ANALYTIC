# %% [markdown]
# JUPYTER IS BEST FOR DATA ANALYSIS

# %%
import numpy as np
import pandas as pd
csv1=pd.read_csv("C:\\Users\\PANDEY JI\\Desktop\\PYTHON\\IPL.csv")
csv1
# Out:
#    id       city                        team1                        team2  \
# 0   1  Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2       Pune               Mumbai Indians       Rising Pune Supergiant
# 2   3     Rajkot                Gujarat Lions        Kolkata Knight Riders
# 3   4     Indore       Rising Pune Supergiant              Kings XI Punjab
# 4   5  Bangalore  Royal Challengers Bangalore             Delhi Daredevils
# 5   6  Hyderabad                Gujarat Lions          Sunrisers Hyderabad
# 6   7     Mumbai        Kolkata Knight Riders               Mumbai Indians
# 7   8     Indore  Royal Challengers Bangalore              Kings XI Punjab
# 8   9       Pune             Delhi Daredevils       Rising Pune Supergiant
# 9  10     Mumbai          Sunrisers Hyderabad               Mumbai Indians
#
#                    toss_winner toss_decision                       winner  \
# ...

# %%
csv1.shape
# Out:
# (10, 9)

# %%
csv1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              10 non-null     int64
#  1   city            10 non-null     str
#  2   team1           10 non-null     str
#  3   team2           10 non-null     str
#  4   toss_winner     10 non-null     str
#  5   toss_decision   10 non-null     str
#  6   winner          10 non-null     str
#  7   win_by_runs     10 non-null     int64
#  8   win_by_wickets  10 non-null     int64
# dtypes: int64(3), str(6)
# memory usage: 852.0 bytes

# %%
csv1.head() #few rows from top
# Out:
#    id       city                        team1                        team2  \
# 0   1  Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2       Pune               Mumbai Indians       Rising Pune Supergiant
# 2   3     Rajkot                Gujarat Lions        Kolkata Knight Riders
# 3   4     Indore       Rising Pune Supergiant              Kings XI Punjab
# 4   5  Bangalore  Royal Challengers Bangalore             Delhi Daredevils
#
#                    toss_winner toss_decision                       winner  \
# 0  Royal Challengers Bangalore         field          Sunrisers Hyderabad
# 1       Rising Pune Supergiant         field       Rising Pune Supergiant
# 2        Kolkata Knight Riders         field        Kolkata Knight Riders
# 3              Kings XI Punjab         field              Kings XI Punjab
# 4  Royal Challengers Bangalore           bat  Royal Challengers Bangalore
#
#    win_by_runs  win_by_wickets
# 0           35               0
# ...

# %%
csv1.head().shape
# Out:
# (5, 9)

# %%
csv1.head(3) #3 rows from top
# Out:
#    id       city                team1                        team2  \
# 0   1  Hyderabad  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2       Pune       Mumbai Indians       Rising Pune Supergiant
# 2   3     Rajkot        Gujarat Lions        Kolkata Knight Riders
#
#                    toss_winner toss_decision                  winner  \
# 0  Royal Challengers Bangalore         field     Sunrisers Hyderabad
# 1       Rising Pune Supergiant         field  Rising Pune Supergiant
# 2        Kolkata Knight Riders         field   Kolkata Knight Riders
#
#    win_by_runs  win_by_wickets
# 0           35               0
# 1            0               7
# 2            0              10

# %%
csv1.tail() #few rows from bottom
# Out:
#    id       city                        team1                   team2  \
# 5   6  Hyderabad                Gujarat Lions     Sunrisers Hyderabad
# 6   7     Mumbai        Kolkata Knight Riders          Mumbai Indians
# 7   8     Indore  Royal Challengers Bangalore         Kings XI Punjab
# 8   9       Pune             Delhi Daredevils  Rising Pune Supergiant
# 9  10     Mumbai          Sunrisers Hyderabad          Mumbai Indians
#
#                    toss_winner toss_decision               winner  \
# 5          Sunrisers Hyderabad         field  Sunrisers Hyderabad
# 6               Mumbai Indians         field       Mumbai Indians
# 7  Royal Challengers Bangalore           bat      Kings XI Punjab
# 8       Rising Pune Supergiant         field     Delhi Daredevils
# 9               Mumbai Indians         field       Mumbai Indians
#
#    win_by_runs  win_by_wickets
# 5            0               9
# 6            0               4
# 7            0               8
# ...

# %%
csv1.tail(3) #3 rows from bottom
# Out:
#    id    city                        team1                   team2  \
# 7   8  Indore  Royal Challengers Bangalore         Kings XI Punjab
# 8   9    Pune             Delhi Daredevils  Rising Pune Supergiant
# 9  10  Mumbai          Sunrisers Hyderabad          Mumbai Indians
#
#                    toss_winner toss_decision            winner  win_by_runs  \
# 7  Royal Challengers Bangalore           bat   Kings XI Punjab            0
# 8       Rising Pune Supergiant         field  Delhi Daredevils           97
# 9               Mumbai Indians         field    Mumbai Indians            0
#
#    win_by_wickets
# 7               8
# 8               0
# 9               4

# %%
csv1.describe() # statisticalvalues for numeric values column
# Out:
#              id  win_by_runs  win_by_wickets
# count  10.00000    10.000000       10.000000
# mean    5.50000    14.700000        4.800000
# std     3.02765    31.087868        3.823901
# min     1.00000     0.000000        0.000000
# 25%     3.25000     0.000000        1.000000
# 50%     5.50000     0.000000        5.000000
# 75%     7.75000    11.250000        7.750000
# max    10.00000    97.000000       10.000000

# %%
csv1['city'] #show a perticular column
# Out:
# 0    Hyderabad
# 1         Pune
# 2       Rajkot
# 3       Indore
# 4    Bangalore
# 5    Hyderabad
# 6       Mumbai
# 7       Indore
# 8         Pune
# 9       Mumbai
# Name: city, dtype: str

# %%
csv1['city'][5] #show a perticular column with perticular row
# Out:
# 'Hyderabad'

# %%
csv1['city'][5]=0 #change a perticular column & perticular row's value with warning.original file wont be changed
# Out:
# C:\Users\PANDEY JI\AppData\Local\Temp\ipykernel_6564\569454076.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   csv1['city'][5]=0 #change a perticular column & perticular row's value with warning.original file wont be changed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ...

# %%
csv1
# Out:
#    id       city                        team1                        team2  \
# 0   1  Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2       Pune               Mumbai Indians       Rising Pune Supergiant
# 2   3     Rajkot                Gujarat Lions        Kolkata Knight Riders
# 3   4     Indore       Rising Pune Supergiant              Kings XI Punjab
# 4   5  Bangalore  Royal Challengers Bangalore             Delhi Daredevils
# 5   6  Hyderabad                Gujarat Lions          Sunrisers Hyderabad
# 6   7     Mumbai        Kolkata Knight Riders               Mumbai Indians
# 7   8     Indore  Royal Challengers Bangalore              Kings XI Punjab
# 8   9       Pune             Delhi Daredevils       Rising Pune Supergiant
# 9  10     Mumbai          Sunrisers Hyderabad               Mumbai Indians
#
#                    toss_winner toss_decision                       winner  \
# ...

# %%
csv1.to_csv('matches_1.csv') #create a new file with changed data

# %%
csv1.index #info about indexes
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
csv1.columns
# Out:
# Index(['id', 'city', 'team1', 'team2', 'toss_winner', 'toss_decision',
#        'winner', 'win_by_runs', 'win_by_wickets'],
#       dtype='str')

# %%
csv1.T #rows and columns will get exchanged
# Out:
#                                           0                       1  \
# id                                        1                       2
# city                              Hyderabad                    Pune
# team1                   Sunrisers Hyderabad          Mumbai Indians
# team2           Royal Challengers Bangalore  Rising Pune Supergiant
# toss_winner     Royal Challengers Bangalore  Rising Pune Supergiant
# toss_decision                         field                   field
# winner                  Sunrisers Hyderabad  Rising Pune Supergiant
# win_by_runs                              35                       0
# win_by_wickets                            0                       7
#
#                                     2                       3  \
# id                                  3                       4
# city                           Rajkot                  Indore
# team1                   Gujarat Lions  Rising Pune Supergiant
# ...

# %%
csv1.head()
# Out:
#    id       city                        team1                        team2  \
# 0   1  Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2       Pune               Mumbai Indians       Rising Pune Supergiant
# 2   3     Rajkot                Gujarat Lions        Kolkata Knight Riders
# 3   4     Indore       Rising Pune Supergiant              Kings XI Punjab
# 4   5  Bangalore  Royal Challengers Bangalore             Delhi Daredevils
#
#                    toss_winner toss_decision                       winner  \
# 0  Royal Challengers Bangalore         field          Sunrisers Hyderabad
# 1       Rising Pune Supergiant         field       Rising Pune Supergiant
# 2        Kolkata Knight Riders         field        Kolkata Knight Riders
# 3              Kings XI Punjab         field              Kings XI Punjab
# 4  Royal Challengers Bangalore           bat  Royal Challengers Bangalore
#
#    win_by_runs  win_by_wickets
# 0           35               0
# ...

# %%
csv1.sort_index(axis=0,ascending = False) #reverse order index axix=0 is row and axis=1 is column
# Out:
#    id       city                        team1                        team2  \
# 9  10     Mumbai          Sunrisers Hyderabad               Mumbai Indians
# 8   9       Pune             Delhi Daredevils       Rising Pune Supergiant
# 7   8     Indore  Royal Challengers Bangalore              Kings XI Punjab
# 6   7     Mumbai        Kolkata Knight Riders               Mumbai Indians
# 5   6  Hyderabad                Gujarat Lions          Sunrisers Hyderabad
# 4   5  Bangalore  Royal Challengers Bangalore             Delhi Daredevils
# 3   4     Indore       Rising Pune Supergiant              Kings XI Punjab
# 2   3     Rajkot                Gujarat Lions        Kolkata Knight Riders
# 1   2       Pune               Mumbai Indians       Rising Pune Supergiant
# 0   1  Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                    toss_winner toss_decision                       winner  \
# ...

# %%
csv1.sort_index(axis=1,ascending = False) #reverse order column
# Out:
#                         winner  win_by_wickets  win_by_runs  \
# 0          Sunrisers Hyderabad               0           35
# 1       Rising Pune Supergiant               7            0
# 2        Kolkata Knight Riders              10            0
# 3              Kings XI Punjab               6            0
# 4  Royal Challengers Bangalore               0           15
# 5          Sunrisers Hyderabad               9            0
# 6               Mumbai Indians               4            0
# 7              Kings XI Punjab               8            0
# 8             Delhi Daredevils               0           97
# 9               Mumbai Indians               4            0
#
#                    toss_winner toss_decision                        team2  \
# 0  Royal Challengers Bangalore         field  Royal Challengers Bangalore
# 1       Rising Pune Supergiant         field       Rising Pune Supergiant
# 2        Kolkata Knight Riders         field        Kolkata Knight Riders
# ...

# %%
csv2=csv1
#its a view mode so csv2 will basically point at csv1's memory location.
#Any changes made in csv2 will be reflected in csv1 as well.

# %%
csv2['city'][0]="prayagraj"
# Out:
# C:\Users\PANDEY JI\AppData\Local\Temp\ipykernel_6564\1436405055.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   csv2['city'][0]="prayagraj"

# %%
csv2.head()
# Out:
#    id       city                        team1                        team2  \
# 0   1  Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2       Pune               Mumbai Indians       Rising Pune Supergiant
# 2   3     Rajkot                Gujarat Lions        Kolkata Knight Riders
# 3   4     Indore       Rising Pune Supergiant              Kings XI Punjab
# 4   5  Bangalore  Royal Challengers Bangalore             Delhi Daredevils
#
#                    toss_winner toss_decision                       winner  \
# 0  Royal Challengers Bangalore         field          Sunrisers Hyderabad
# 1       Rising Pune Supergiant         field       Rising Pune Supergiant
# 2        Kolkata Knight Riders         field        Kolkata Knight Riders
# 3              Kings XI Punjab         field              Kings XI Punjab
# 4  Royal Challengers Bangalore           bat  Royal Challengers Bangalore
#
#    win_by_runs  win_by_wickets
# 0           35               0
# ...

# %%
csv1.head()
# Out:
#    id       city                        team1                        team2  \
# 0   1  Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2       Pune               Mumbai Indians       Rising Pune Supergiant
# 2   3     Rajkot                Gujarat Lions        Kolkata Knight Riders
# 3   4     Indore       Rising Pune Supergiant              Kings XI Punjab
# 4   5  Bangalore  Royal Challengers Bangalore             Delhi Daredevils
#
#                    toss_winner toss_decision                       winner  \
# 0  Royal Challengers Bangalore         field          Sunrisers Hyderabad
# 1       Rising Pune Supergiant         field       Rising Pune Supergiant
# 2        Kolkata Knight Riders         field        Kolkata Knight Riders
# 3              Kings XI Punjab         field              Kings XI Punjab
# 4  Royal Challengers Bangalore           bat  Royal Challengers Bangalore
#
#    win_by_runs  win_by_wickets
# 0           35               0
# ...

# %%
csv3=csv1.copy() # Its a copy mode in which a copy of csv1 will be copied in csv3
#and any changes made in csv3 will not be reflected in csv1

# %%
csv3['city'][1]='GreNo'
# Out:
# C:\Users\PANDEY JI\AppData\Local\Temp\ipykernel_6564\3909947299.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   csv3['city'][1]='GreNo'

# %%
csv1.head() #no change in original file csv1
# Out:
#    id       city                        team1                        team2  \
# 0   1  Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2       Pune               Mumbai Indians       Rising Pune Supergiant
# 2   3     Rajkot                Gujarat Lions        Kolkata Knight Riders
# 3   4     Indore       Rising Pune Supergiant              Kings XI Punjab
# 4   5  Bangalore  Royal Challengers Bangalore             Delhi Daredevils
#
#                    toss_winner toss_decision                       winner  \
# 0  Royal Challengers Bangalore         field          Sunrisers Hyderabad
# 1       Rising Pune Supergiant         field       Rising Pune Supergiant
# 2        Kolkata Knight Riders         field        Kolkata Knight Riders
# 3              Kings XI Punjab         field              Kings XI Punjab
# 4  Royal Challengers Bangalore           bat  Royal Challengers Bangalore
#
#    win_by_runs  win_by_wickets
# 0           35               0
# ...

# %%
csv3.head() #only changes are made in csv3
# Out:
#    id       city                        team1                        team2  \
# 0   1  Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2       Pune               Mumbai Indians       Rising Pune Supergiant
# 2   3     Rajkot                Gujarat Lions        Kolkata Knight Riders
# 3   4     Indore       Rising Pune Supergiant              Kings XI Punjab
# 4   5  Bangalore  Royal Challengers Bangalore             Delhi Daredevils
#
#                    toss_winner toss_decision                       winner  \
# 0  Royal Challengers Bangalore         field          Sunrisers Hyderabad
# 1       Rising Pune Supergiant         field       Rising Pune Supergiant
# 2        Kolkata Knight Riders         field        Kolkata Knight Riders
# 3              Kings XI Punjab         field              Kings XI Punjab
# 4  Royal Challengers Bangalore           bat  Royal Challengers Bangalore
#
#    win_by_runs  win_by_wickets
# 0           35               0
# ...

# %%
csv2.loc[3,'city']='nainital' #no error will show.

# %%
csv2
# Out:
#    id       city                        team1                        team2  \
# 0   1  Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2       Pune               Mumbai Indians       Rising Pune Supergiant
# 2   3     Rajkot                Gujarat Lions        Kolkata Knight Riders
# 3   4   nainital       Rising Pune Supergiant              Kings XI Punjab
# 4   5  Bangalore  Royal Challengers Bangalore             Delhi Daredevils
# 5   6  Hyderabad                Gujarat Lions          Sunrisers Hyderabad
# 6   7     Mumbai        Kolkata Knight Riders               Mumbai Indians
# 7   8     Indore  Royal Challengers Bangalore              Kings XI Punjab
# 8   9       Pune             Delhi Daredevils       Rising Pune Supergiant
# 9  10     Mumbai          Sunrisers Hyderabad               Mumbai Indians
#
#                    toss_winner toss_decision                       winner  \
# ...

# %%
csv2[0]='pooja'

# %%
csv2
# Out:
#    id       city                        team1                        team2  \
# 0   1  Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2       Pune               Mumbai Indians       Rising Pune Supergiant
# 2   3     Rajkot                Gujarat Lions        Kolkata Knight Riders
# 3   4   nainital       Rising Pune Supergiant              Kings XI Punjab
# 4   5  Bangalore  Royal Challengers Bangalore             Delhi Daredevils
# 5   6  Hyderabad                Gujarat Lions          Sunrisers Hyderabad
# 6   7     Mumbai        Kolkata Knight Riders               Mumbai Indians
# 7   8     Indore  Royal Challengers Bangalore              Kings XI Punjab
# 8   9       Pune             Delhi Daredevils       Rising Pune Supergiant
# 9  10     Mumbai          Sunrisers Hyderabad               Mumbai Indians
#
#                    toss_winner toss_decision                       winner  \
# ...

# %%
csv2.drop(5) #dropped the 5th row
# Out:
#    id       city                        team1                        team2  \
# 0   1  Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2       Pune               Mumbai Indians       Rising Pune Supergiant
# 2   3     Rajkot                Gujarat Lions        Kolkata Knight Riders
# 3   4   nainital       Rising Pune Supergiant              Kings XI Punjab
# 4   5  Bangalore  Royal Challengers Bangalore             Delhi Daredevils
# 6   7     Mumbai        Kolkata Knight Riders               Mumbai Indians
# 7   8     Indore  Royal Challengers Bangalore              Kings XI Punjab
# 8   9       Pune             Delhi Daredevils       Rising Pune Supergiant
# 9  10     Mumbai          Sunrisers Hyderabad               Mumbai Indians
#
#                    toss_winner toss_decision                       winner  \
# 0  Royal Challengers Bangalore         field          Sunrisers Hyderabad
# ...

# %%
csv2.drop(0,axis=1) #dropped the column named 0.
# Out:
#    id       city                        team1                        team2  \
# 0   1  Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2       Pune               Mumbai Indians       Rising Pune Supergiant
# 2   3     Rajkot                Gujarat Lions        Kolkata Knight Riders
# 3   4   nainital       Rising Pune Supergiant              Kings XI Punjab
# 4   5  Bangalore  Royal Challengers Bangalore             Delhi Daredevils
# 5   6  Hyderabad                Gujarat Lions          Sunrisers Hyderabad
# 6   7     Mumbai        Kolkata Knight Riders               Mumbai Indians
# 7   8     Indore  Royal Challengers Bangalore              Kings XI Punjab
# 8   9       Pune             Delhi Daredevils       Rising Pune Supergiant
# 9  10     Mumbai          Sunrisers Hyderabad               Mumbai Indians
#
#                    toss_winner toss_decision                       winner  \
# ...

# %%
csv2.loc[[3,4],['city','winner']]
# Out:
#         city                       winner
# 3   nainital              Kings XI Punjab
# 4  Bangalore  Royal Challengers Bangalore

# %%
csv2.loc[[3,4],:]
# Out:
#    id       city                        team1             team2  \
# 3   4   nainital       Rising Pune Supergiant   Kings XI Punjab
# 4   5  Bangalore  Royal Challengers Bangalore  Delhi Daredevils
#
#                    toss_winner toss_decision                       winner  \
# 3              Kings XI Punjab         field              Kings XI Punjab
# 4  Royal Challengers Bangalore           bat  Royal Challengers Bangalore
#
#    win_by_runs  win_by_wickets      0
# 3            0               6  pooja
# 4           15               0  pooja

# %%
csv2.loc[(csv2['toss_decision'] =='field')]
# Out:
#    id       city                   team1                        team2  \
# 0   1  Hyderabad     Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2       Pune          Mumbai Indians       Rising Pune Supergiant
# 2   3     Rajkot           Gujarat Lions        Kolkata Knight Riders
# 3   4   nainital  Rising Pune Supergiant              Kings XI Punjab
# 5   6  Hyderabad           Gujarat Lions          Sunrisers Hyderabad
# 6   7     Mumbai   Kolkata Knight Riders               Mumbai Indians
# 8   9       Pune        Delhi Daredevils       Rising Pune Supergiant
# 9  10     Mumbai     Sunrisers Hyderabad               Mumbai Indians
#
#                    toss_winner toss_decision                  winner  \
# 0  Royal Challengers Bangalore         field     Sunrisers Hyderabad
# 1       Rising Pune Supergiant         field  Rising Pune Supergiant
# 2        Kolkata Knight Riders         field   Kolkata Knight Riders
# ...

# %%
csv2.loc[(csv2['toss_decision'] =='field')& (csv2['city'] =='Mumbai' )]
# Out:
#    id    city                  team1           team2     toss_winner  \
# 6   7  Mumbai  Kolkata Knight Riders  Mumbai Indians  Mumbai Indians
# 9  10  Mumbai    Sunrisers Hyderabad  Mumbai Indians  Mumbai Indians
#
#   toss_decision          winner  win_by_runs  win_by_wickets      0
# 6         field  Mumbai Indians            0               4  pooja
# 9         field  Mumbai Indians            0               4  pooja

# %%
csv2.iloc[0,6] #show 0th row and 6th column value
# Out:
# 'Sunrisers Hyderabad'

# %%
csv2.iloc[[0,6],[2,5]]
# Out:
#                    team1 toss_decision
# 0    Sunrisers Hyderabad         field
# 6  Kolkata Knight Riders         field

# %%
csv2.head(3)
# Out:
#    id       city                team1                        team2  \
# 0   1  Hyderabad  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2       Pune       Mumbai Indians       Rising Pune Supergiant
# 2   3     Rajkot        Gujarat Lions        Kolkata Knight Riders
#
#                    toss_winner toss_decision                  winner  \
# 0  Royal Challengers Bangalore         field     Sunrisers Hyderabad
# 1       Rising Pune Supergiant         field  Rising Pune Supergiant
# 2        Kolkata Knight Riders         field   Kolkata Knight Riders
#
#    win_by_runs  win_by_wickets      0
# 0           35               0  pooja
# 1            0               7  pooja
# 2            0              10  pooja

# %%
csv2.drop([1]) #delete row 1
# Out:
#    id       city                        team1                        team2  \
# 0   1  Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 2   3     Rajkot                Gujarat Lions        Kolkata Knight Riders
# 3   4   nainital       Rising Pune Supergiant              Kings XI Punjab
# 4   5  Bangalore  Royal Challengers Bangalore             Delhi Daredevils
# 5   6  Hyderabad                Gujarat Lions          Sunrisers Hyderabad
# 6   7     Mumbai        Kolkata Knight Riders               Mumbai Indians
# 7   8     Indore  Royal Challengers Bangalore              Kings XI Punjab
# 8   9       Pune             Delhi Daredevils       Rising Pune Supergiant
# 9  10     Mumbai          Sunrisers Hyderabad               Mumbai Indians
#
#                    toss_winner toss_decision                       winner  \
# 0  Royal Challengers Bangalore         field          Sunrisers Hyderabad
# ...

# %%
csv2.drop([0],axis=1) #delete column named 0
# Out:
#    id       city                        team1                        team2  \
# 0   1  Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2       Pune               Mumbai Indians       Rising Pune Supergiant
# 2   3     Rajkot                Gujarat Lions        Kolkata Knight Riders
# 3   4   nainital       Rising Pune Supergiant              Kings XI Punjab
# 4   5  Bangalore  Royal Challengers Bangalore             Delhi Daredevils
# 5   6  Hyderabad                Gujarat Lions          Sunrisers Hyderabad
# 6   7     Mumbai        Kolkata Knight Riders               Mumbai Indians
# 7   8     Indore  Royal Challengers Bangalore              Kings XI Punjab
# 8   9       Pune             Delhi Daredevils       Rising Pune Supergiant
# 9  10     Mumbai          Sunrisers Hyderabad               Mumbai Indians
#
#                    toss_winner toss_decision                       winner  \
# ...

# %%
csv2 #column 0 is not deleted from original data
# Out:
#    id       city                        team1                        team2  \
# 0   1  Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2       Pune               Mumbai Indians       Rising Pune Supergiant
# 2   3     Rajkot                Gujarat Lions        Kolkata Knight Riders
# 3   4   nainital       Rising Pune Supergiant              Kings XI Punjab
# 4   5  Bangalore  Royal Challengers Bangalore             Delhi Daredevils
# 5   6  Hyderabad                Gujarat Lions          Sunrisers Hyderabad
# 6   7     Mumbai        Kolkata Knight Riders               Mumbai Indians
# 7   8     Indore  Royal Challengers Bangalore              Kings XI Punjab
# 8   9       Pune             Delhi Daredevils       Rising Pune Supergiant
# 9  10     Mumbai          Sunrisers Hyderabad               Mumbai Indians
#
#                    toss_winner toss_decision                       winner  \
# ...

# %%
#csv2=csv2.drop([0],axis=1) # column 0 get deleted permanently from original file. (1st method)
csv2.drop([0],axis=1,inplace=True) # column 0 get deleted permanently from original file.(2nd method)

# %%
csv2
# Out:
#    id       city                        team1                        team2  \
# 0   1  Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2       Pune               Mumbai Indians       Rising Pune Supergiant
# 2   3     Rajkot                Gujarat Lions        Kolkata Knight Riders
# 3   4   nainital       Rising Pune Supergiant              Kings XI Punjab
# 4   5  Bangalore  Royal Challengers Bangalore             Delhi Daredevils
# 5   6  Hyderabad                Gujarat Lions          Sunrisers Hyderabad
# 6   7     Mumbai        Kolkata Knight Riders               Mumbai Indians
# 7   8     Indore  Royal Challengers Bangalore              Kings XI Punjab
# 8   9       Pune             Delhi Daredevils       Rising Pune Supergiant
# 9  10     Mumbai          Sunrisers Hyderabad               Mumbai Indians
#
#                    toss_winner toss_decision                       winner  \
# ...

# %%
csv2.drop(['winner','toss_decision'],axis=1,inplace=True)

# %%
csv2.drop([2,4],axis=0,inplace=True)

# %%
csv2 #row 2 and 4 and colum winner and toss_decision are deleted from original file permanently
# Out:
#    id       city                        team1                        team2  \
# 0   1  Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2       Pune               Mumbai Indians       Rising Pune Supergiant
# 3   4   nainital       Rising Pune Supergiant              Kings XI Punjab
# 5   6  Hyderabad                Gujarat Lions          Sunrisers Hyderabad
# 6   7     Mumbai        Kolkata Knight Riders               Mumbai Indians
# 7   8     Indore  Royal Challengers Bangalore              Kings XI Punjab
# 8   9       Pune             Delhi Daredevils       Rising Pune Supergiant
# 9  10     Mumbai          Sunrisers Hyderabad               Mumbai Indians
#
#                    toss_winner  win_by_runs  win_by_wickets
# 0  Royal Challengers Bangalore           35               0
# 1       Rising Pune Supergiant            0               7
# 3              Kings XI Punjab            0               6
# ...

# %%
csv2.head()
# Out:
#    id       city                   team1                        team2  \
# 0   1  Hyderabad     Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2       Pune          Mumbai Indians       Rising Pune Supergiant
# 3   4   nainital  Rising Pune Supergiant              Kings XI Punjab
# 5   6  Hyderabad           Gujarat Lions          Sunrisers Hyderabad
# 6   7     Mumbai   Kolkata Knight Riders               Mumbai Indians
#
#                    toss_winner  win_by_runs  win_by_wickets
# 0  Royal Challengers Bangalore           35               0
# 1       Rising Pune Supergiant            0               7
# 3              Kings XI Punjab            0               6
# 5          Sunrisers Hyderabad            0               9
# 6               Mumbai Indians            0               4

# %%
csv2.reset_index() #to reset index but one column index is also there.
# Out:
#    index  id       city                        team1  \
# 0      0   1  Hyderabad          Sunrisers Hyderabad
# 1      1   2       Pune               Mumbai Indians
# 2      3   4   nainital       Rising Pune Supergiant
# 3      5   6  Hyderabad                Gujarat Lions
# 4      6   7     Mumbai        Kolkata Knight Riders
# 5      7   8     Indore  Royal Challengers Bangalore
# 6      8   9       Pune             Delhi Daredevils
# 7      9  10     Mumbai          Sunrisers Hyderabad
#
#                          team2                  toss_winner  win_by_runs  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore           35
# 1       Rising Pune Supergiant       Rising Pune Supergiant            0
# 2              Kings XI Punjab              Kings XI Punjab            0
# 3          Sunrisers Hyderabad          Sunrisers Hyderabad            0
# 4               Mumbai Indians               Mumbai Indians            0
# ...

# %%
csv2.reset_index(drop=True,inplace=True) #index column will be removed

# %%
csv2['win_by_runs']=None #make this column value as None

# %%
csv2
# Out:
#    id       city                        team1                        team2  \
# 0   1  Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2       Pune               Mumbai Indians       Rising Pune Supergiant
# 2   4   nainital       Rising Pune Supergiant              Kings XI Punjab
# 3   6  Hyderabad                Gujarat Lions          Sunrisers Hyderabad
# 4   7     Mumbai        Kolkata Knight Riders               Mumbai Indians
# 5   8     Indore  Royal Challengers Bangalore              Kings XI Punjab
# 6   9       Pune             Delhi Daredevils       Rising Pune Supergiant
# 7  10     Mumbai          Sunrisers Hyderabad               Mumbai Indians
#
#                    toss_winner win_by_runs  win_by_wickets
# 0  Royal Challengers Bangalore        None               0
# 1       Rising Pune Supergiant        None               7
# 2              Kings XI Punjab        None               6
# ...

# %%
csv2.isnull() #return True for Null/None values rest will be False
# Out:
#       id   city  team1  team2  toss_winner  win_by_runs  win_by_wickets
# 0  False  False  False  False        False         True           False
# 1  False  False  False  False        False         True           False
# 2  False  False  False  False        False         True           False
# 3  False  False  False  False        False         True           False
# 4  False  False  False  False        False         True           False
# 5  False  False  False  False        False         True           False
# 6  False  False  False  False        False         True           False
# 7  False  False  False  False        False         True           False

# %%
csv2['win_by_runs'].isnull() #return True for Null/None values
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# Name: win_by_runs, dtype: bool

# %%
csv2['win_by_runs']=99 #make this column value as 99

# %%
csv2
# Out:
#    id       city                        team1                        team2  \
# 0   1  Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2       Pune               Mumbai Indians       Rising Pune Supergiant
# 2   4   nainital       Rising Pune Supergiant              Kings XI Punjab
# 3   6  Hyderabad                Gujarat Lions          Sunrisers Hyderabad
# 4   7     Mumbai        Kolkata Knight Riders               Mumbai Indians
# 5   8     Indore  Royal Challengers Bangalore              Kings XI Punjab
# 6   9       Pune             Delhi Daredevils       Rising Pune Supergiant
# 7  10     Mumbai          Sunrisers Hyderabad               Mumbai Indians
#
#                    toss_winner  win_by_runs  win_by_wickets
# 0  Royal Challengers Bangalore           99               0
# 1       Rising Pune Supergiant           99               7
# 2              Kings XI Punjab           99               6
# ...

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
 "toy": [np.nan, 'Batmobile', 'Bullwhip'],
 "born": [pd.NaT, pd.Timestamp("1940-04-25"),
 pd.NaT]})

# %%
df
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna() #drop rows and column having values NA
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.dropna(how='all') #wont drop till all values of row or column is NA
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df1 = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
 "toy": [np.nan, np.nan, np.nan],
 "born": [pd.NaT, pd.Timestamp("1940-04-25"),
 pd.NaT]})

# %%
df1
# Out:
#        name  toy       born
# 0    Alfred  NaN        NaT
# 1    Batman  NaN 1940-04-25
# 2  Catwoman  NaN        NaT

# %%
df1.dropna(how='all',axis=1)
# Out:
#        name       born
# 0    Alfred        NaT
# 1    Batman 1940-04-25
# 2  Catwoman        NaT

# %%
df1
# Out:
#        name  toy       born
# 0    Alfred  NaN        NaT
# 1    Batman  NaN 1940-04-25
# 2  Catwoman  NaN        NaT

# %%
df2 = pd.DataFrame({"name": [np.nan, 'Batman', 'Catwoman'],
 "toy": [np.nan, 'Batmobile', 'Bullwhip'],
 "born": [pd.NaT, pd.Timestamp("1940-04-25"),
 pd.NaT]})

# %%
df2
# Out:
#        name        toy       born
# 0       NaN        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df2.dropna(how='all')
# Out:
#        name        toy       born
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df2
# Out:
#        name        toy       born
# 0       NaN        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df3 = pd.DataFrame({"name": ['Alfred', 'Batman', 'Alfred'],
 "toy": [np.nan, 'Batmobile', 'Bullwhip'],
 "born": [pd.NaT, pd.Timestamp("1940-04-25"),
 pd.NaT]})

# %%
df3
# Out:
#      name        toy       born
# 0  Alfred        NaN        NaT
# 1  Batman  Batmobile 1940-04-25
# 2  Alfred   Bullwhip        NaT

# %%
df3.drop_duplicates(subset=['name']) #drop the row having duplicate value in column 'name'.Bydefault keep='first' is there which means first value will be kept and rest will be dropped.
# Out:
#      name        toy       born
# 0  Alfred        NaN        NaT
# 1  Batman  Batmobile 1940-04-25

# %%
df3.drop_duplicates(subset=['name'],keep='last') #droped duplicate value.Keeps second value
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25
# 2  Alfred   Bullwhip        NaT

# %%
df3.drop_duplicates(subset=['name'],keep=False) #droped all duplicate value from file.
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df3.shape # no. of rows and columns
# Out:
# (3, 3)

# %%
df3.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      str
#  1   toy     2 non-null      str
#  2   born    1 non-null      datetime64[us]
# dtypes: datetime64[us](1), str(2)
# memory usage: 204.0 bytes
